# %%
""" 
    Docstring
    
Introduction: 
    
This is an interactive story about the famous novel and movie named:
The Jungle Book. In the game, the user will be playing as Mowgli, a child 
that after an attack from Shere Khan the tiger, to the village where his 
parents lived, is lost in the jungle. He is then raised by wolves and will go 
through a series of adventures in the jungle, where he will meet great friends
like Bagheera the black panther, who will teach him how to hunt, and Baloo the
bear, who will teach him the laws of the jungle.


Hope you enjoy the game!
"""

# The while loop from scene 4 using try: and except: I did not know how to do
# it, I researched, and found in the following link in stackoverflow a loop 
# that did pretty much what my goal was, thus, I took the concept behind it, 
# modified and applied it to my code. Also, the randrange link will be
# provided since we have not used it in class either.
# The use of (not in) in loops I knew from before in my first year of school,
# before dropping out engineering.
# https://stackoverflow.com/questions/23326099/how-can-i-limit-the-user-input-to-only-integers-in-python
# https://www.geeksforgeeks.org/randrange-in-python/

# Importing random to generate a random number for scene 3 & 4.
import random as rd

# If there is any specific requirement in the answer it will be mentioned.
# The function print will be used to display information or to space text.
# Using .lower() to make input lower case that way any answer is controlled.
# Using .capitalize to make the answer start with capital letter.

# Printing out an introduction to the game to put user into context.
print ("""
Hi Mowgli, whilst living with the wolves you hear that there is an imminent 
threat of Shere Khan, that has set on you his target. You are forced to leave
the pack. Your friend Bagheera takes you away in order to take you back to 
the human civilization.\n
           """)

# Creating a function that will be the opening scene of the game.
def scene_1():

# Input of the first user answer to the story.
# Using prompt for placing.

    civilization_1 = input(prompt ="""
Bagheera asks you if agree, do you? 

Answer the question including 'yes' or 'no':\n""").lower().capitalize()
    print("""\n""")
    
# Creating a loop in case wrong answer is given to the game.
    while (("yes") not in civilization_1 and ("no") not in civilization_1 
           and ("No") not in civilization_1 and ("Yes") not in civilization_1):       
        print ("""You have made a mistake, please answer again.\n""")
        
# User input for development.        
        civilization_1 = input(prompt ="""
Bagheera asks you if agree, do you? 

Answer the question including 'yes' or 'no':\n""").lower().capitalize()
        
# Creating conditions to give the user options to see where the story goes.    
    if ("no") in civilization_1 or ("No") in civilization_1:        
        print (f"""
You scream to her: {civilization_1}!, nevertheless she does not care about 
you answer and is going to take you back anyway. She knows that Shere Khan
will find you and the jungle is too dangerous for you.\n""")

# Creating a second input for the user.
# Using prompt for placing issues.
        civilization_2 = input(prompt ="""
Since Bagheera has not cared about your opinion, you have to make a choice,
do you run away from her o to still follow her.

Answer including 'follow' or 'run':\n""").lower().capitalize()
    
# Creating loop to repeat answer in case wrong one is given to game.    
        while (("run") not in civilization_2 
               and ("follow") not in civilization_2 
               and ("Follow") not in civilization_2 
               and ("Run") not in civilization_2):
            print ("""
You have made a mistake, please answer again.\n""")            
            civilization_2 = input(prompt = """
Answer including 'follow' or 'run':\n""").lower().capitalize()

# Second conditional statements for user.            
        if ("run") in civilization_2 or ("Run") in civilization_2:
            print("""\n""")  
            print(f"""
You have decided to: {civilization_2 }, thus you got lost in the jungle,
Shere Khan found you before Bagheera and you have died.\n""")
            
# Calling replay since you died.
            replay()
            
# End to second condition.    
        else:
            print("""\n""")  
            print(f"""
Even though you are angry at her you think it is best to decide to:
{civilization_2}. She tells you to get up a tree to sleep in a secure place 
for the night, and you do just so.\n""")
            
# Calling scene 2 to advance.
            scene_2()
    
# End to first condition.            
    else: 
        print("""\n""")  
        print (f"""
You scream to her: {civilization_1}!, she is pleased to see that you are 
being reasonable, and that the jungle is too dangerous for you. She tells you
to go up a tree for the night and you do just so. \n""")
        scene_2()
# Defining the function for scene 2.
def scene_2():
    
    print ("""
You are up in the tree, but a sudden voice appears making you sleepy and 
confused. You do not know what you should do since the same is happening to 
Bagheera.""")

# User input for development.    
    tree_1 = input(prompt = 
"""What do you do? - Please choose a number or the text in the answer.

1 - Jump of the tree.
2 - Try to wake Bagheera up.
3 - Scream for help.\n""").lower().capitalize()

# Creating loop to avoid giving program wrong answer.  
    while (('1') not in tree_1 and ('2') not in tree_1 
           and ('3') not in tree_1 and ('Jump') not in tree_1
           and ('jump') not in tree_1 and ('tree') not in tree_1 
           and ('Tree') not in tree_1 and ('Try') not in tree_1 
           and ('try') not in tree_1 and ('Wake') not in tree_1
           and ('wake') not in tree_1 and ('bagheera') not in tree_1
           and ('Bagheera') not in tree_1 and ('Up') not in tree_1 
           and ('up') not in tree_1 and ('Help') not in tree_1 
           and ('help') not in tree_1 and ('Scream') not in tree_1 
           and ('scream') not in tree_1):
        
        print("You have made a mistake.\n")
        
        tree_1 = input(prompt = """
What do you do? - Please choose either '1', '2' or '3' or the text.\n""")

# Creating conditions for user about what to do in the tree.    
    if (('1') in tree_1 or ('jump') in tree_1 or ('Jump') in tree_1 
        or ('tree') in tree_1 or ('Tree') in tree_1):
        print("""\n""")                 
        print("""
You jump and die because of the height. Kaa appears, kills and eats Bagheera 
and when Shere Khan finds you dead, feasts on you.\n""")
        
# Calling replay function.
        replay()
                       
    elif (('2') in tree_1 or ('Try') in tree_1 or ('try') in tree_1 
        or ('Wake') in tree_1 or ('wake') in tree_1 or ('up') in tree_1 
        or ('Up') in tree_1 or ('Bagheera') in tree_1 
        or ('bagheera') in tree_1):
        print("""\n""")  
        print("""
She does not wake up, you are defenseless and Kaa appears, killing Bagheera 
and eats her, handing you over to Shere Khan, who feasts on you.\n""")
        replay()
# Calling replay function.
        
    else:
        print("""\n""")  
        print ("""It seems like nothing happened, you se Kaa the snake, she is
hypnotizing Bagheera, you can either make her hypnotize you, what would you
do?\n""")
        tree_2 = input(prompt = """
Make her notice you and get hypnotized, or let her hypnotize Bagheera?

Please answer including 'me' or 'her'.\n""").lower().capitalize()

# Creating loop to avoid giving wrong answer.        
        while (('Me') not in tree_2 and ('Her') not in tree_2 
               and ('her') not in tree_2 and ('me') not in tree_2):
            
            print("You made a mistake.")
            
            tree_2 = input(prompt = 
"""Please answer including 'me' or 'her'.\n""").lower().capitalize()
            
# Creating new conditions.        
        if ('Me') in tree_2 or ('me') in tree_2:
            print("""\n""")  
            print("""
Bagheera is free to fight Kaa, she is struggling, but Baloo heard your scream,
he joins and they push Kaa off the tree, saving both of you. You three get 
away together.""")
            
# Calling scene 3 to advance.
            scene_3()   
            
        else:
            print("""\n""")  
            print("""
You try to fight off Kaa but you can't fight her, she kills Bagheera and 
eats her, handing you over to Shere Khan, who feasts on you.""")
# Calling replay function.
            replay()
# Defining scene 3.            
def scene_3():
    print("""
You have survived Kaa and you leave with Bagheera and Baloo. Bagheera goes out
for food getting lost, you stay with Baloo, who gets attacked by monkeys.
You get kidnapped by them and end up at King Louie's palace...\n""")


# Creating a variable to store a random number.    
    palace_1 = str(rd.randint(5,9))
    
# User input for development.    
    palace_2 = input(prompt = """
King Loiue is asking to figure out how many bananas he has eaten today, if you 
miss, he will kill you, he tells you it is more than 4 but less than 10 he has 
given you 4 chances to figure it out.

What is your first guess?\n""")

# Creating loop to avoid giving program wrong answers.    
    while (palace_2 != ('5') and palace_2 != ('6') and palace_2 != ('7')
           and palace_2 != ('8') and palace_2 != ('9')):
        print("""You have made a mistake""")
        palace_2 = input(prompt = """ 
Please insert a number between 5 to 9.""")  
    count = 3
# Creating loop for guessing game.        
    while count>0:

# Creating conditions of the guessing game.
        if palace_1 == palace_2:
            print("""
You won, Bagheera and Baloo appear out of nowhere, fighting and killing King 
Louie, thus, all the other monkeys decide to run away. You get away safely and
head out together.\n""")   
            
# Calling scene 4 to advance.            
            scene_4()
# Break to stop loop in case condition is met.    
            break
        
        elif palace_1 != palace_2:
            
            palace_2 = input(prompt = """ New guess:\n""")
                
# Creating loop to avoid wrong answers.            
            while (palace_2 != ('5') and palace_2 != ('6') 
                   and palace_2 != ('7') and palace_2 != ('8') 
                   and palace_2 != ('9')):
                print("""You have made a mistake.""")
                palace_2 = input(prompt = """ 
Please insert a number between 5 to 9.\n""")
# Setting more conditions for guessing game.
            if palace_2 == palace_1:
                
                print("""
You won, Bagheera and Baloo appear out of nowhere, fighting and killing King 
Louie, thus, all the other scared monkeys decide to run away. You get away
safely and head out together.\n""") 

# Calling scene 4 to advance.
                scene_4()
# Break to stop loop.
                break
# Looping limit.                
            else:
                count -= 1
                if count == 0:
                    if palace_1 != palace_2:
                
                        print (f"""
You have lost and King Louie has killed you to use you as fertilizer for his 
favorite banana tree, number was: {palace_1}.""")
                        replay()
                    else:
                        continue
                else:
                    continue
# Calling replay function since you died.  
              
        else:
            print (f"""
You have lost and King Louie has killed you to use you as fertilizer for his 
favorite banana tree, number was: {palace_1}""")

# Defining scene 4.
def scene_4():
    print("""
You have gotten away from King Louie's palace, and you come across a bunch of
elephants. They are not letting you through. Since they are very intelligent 
creatures, they want you to solve a mathematical problem, and if you do so,
they will let you through. The problem is the following:
    
You will be given a random even number from cero to one hundred. You have to 
add half of the number to it. If you get it right you will go through, if not,
you will be stepped over by the whole group of them.\n""")
# Generating a random even number from 0-100.
    rand_1 = rd.randrange(0,100,2)
    print(f"""The number that the elephants have given you is: {rand_1}""")
# Final value of the variable.    
    rand_ans = rand_1 + (rand_1/2)
# Creating the mentioned loop at the start to avoid a non-integer answer.    
    while True:
        try:
            user_ans = int(input(prompt = """
Answer the with an integer :\n"""))
            break
        except:
            print("You have made a mistake please input an integer")
# Setting up conditions.            
    if user_ans == rand_ans:
        print ("""You have won, and thus, you are allowed through!""")
# Advancing to scene 5.        
        scene_5()
    else:
        print(f"""
The anser was {rand_ans}. The elephants do not think that such a creature 
should be alive, thus they kill you by stepping on you.""")
# Calling replay function since you have failed.
        replay()

# Defining scene 5. 
def scene_5():
    print("""
You have been allowed to cross, but Shere Khan has found you, the only way to 
defend yourself is to pick two of the following things, only two will make you 
defeat Shere Khan.

Which one will you choose?\n""")
    
# Creating list of things user can use.    
    tiger_things = ['Spear', 'Knife', 'Fire stick', 'Rock', 'Baloo', 'Shield']
    
# Creating a loop to print list.    
    for i in tiger_things:
        print(i)
    print("""\n""")

# Creating a empty list to append users choices.    
    chosen_things = []
    print("""\n""")
    
# User input for development.    
    choice_1 = input(prompt = """
Chose your first object.\n""").lower().capitalize()
    
# Creating while loop to avoid giving wrong answers.    
    while (('Spear') not in choice_1 and ('Knife') not in choice_1 
           and ('Fire stick') not in choice_1 and ('Rock') not in choice_1 
           and ('Baloo') not in choice_1 and ('Shield') not in choice_1
           and('spear') not in choice_1 and ('knife') not in choice_1 
           and ('fire stick') not in choice_1 and ('rock') not in choice_1 
           and ('baloo') not in choice_1 and ('shield') not in choice_1):
        print("You have made a mistake.\n")
        print("""\n""")
        choice_1 = input(prompt = 
"""Please choose from the list.\n""").lower().capitalize()

# User input for development.        
    choice_2 = input(prompt = """Chose your second object.\n"""
                     ).lower().capitalize()
    print("""\n""")
    
# Creating while loop to avoid wrong answers.    
    while (('Spear') not in choice_2 and ('Knife') not in choice_2 
           and ('Fire stick') not in choice_2 and ('Rock') not in choice_2 
           and ('Baloo') not in choice_2 and ('Shield') not in choice_2
           and('spear') not in choice_2 and ('knife') not in choice_2 
           and ('fire stick') not in choice_2 and ('rock') not in choice_2 
           and ('baloo') not in choice_2 and ('shield') not in choice_2):
        print("You have made a mistake.\n")       
        choice_2 = input(prompt = 
"""Please choose from the list.\n""").lower().capitalize()
    
# Appending choices to empty list.
    chosen_things.append(choice_1)
    chosen_things.append(choice_2)
 
    print ("""You have chosen to pick these things to fight Shere Khan!\n""")
    
# Creating for loop to print user's choices.    
    for j in chosen_things:
        print (j)
    print("""\n""")
    
# Setting up conditions to winning.    
    if (('baloo') in chosen_things[0] or ('baloo') in chosen_things[1]
        and ('fire stick') in chosen_things[0] 
        or ('fire stick') in chosen_things[1] 
        and ('Baloo') in chosen_things[0] or ('Baloo') in chosen_things[1]
        and ('Fire stick') in chosen_things[0] 
        or ('Fire stick') in chosen_things[1]):
        
        
        print("""
You have killed Shere Khan and survived, now you can rest in peace and enjoy
the jungle!\nGood job!""")
        
# Calling replay function since you won and finished.        
        replay()  
     
    else:
        print("""
With the things you chose, you have not been able to kill Shere Khan, and 
because of a sloppy mistake, he has been able to kill you.""")
# Calling replay since you died. 
        replay()


# Creating a replay function.
def replay():
    
# User input to get data.    
    replay = input(prompt= 
"""Do you want to play again?
Answer 'yes' to continue or 'no' to quit:\n""").lower().capitalize()

# Creating while loop to avoid giving game wrong information.
    while (('Yes') not in replay and ('No') not in replay 
           and ('yes') not in replay and ('no') not in replay):
        print ('You made a mistake')
        replay = input(prompt = """
Please answer including 'yes' or 'no'.\n""").lower().capitalize()
            
# Creating conditions for going back to scenes.    
    if ('yes') in replay or ('Yes') in replay:
        replay_1 = input(prompt = """
Where do you want to restart? 
Answer the number either in words or numbers the scene you are in to restart 
it from there or either '1' or 'one' to fully restart.\n"""
).lower().capitalize()

# Loop to avoid mistakes given to game.
        while (('1') not in replay_1  and ('2') not in replay_1 
               and ('3') not in replay_1 and ('4') not in replay_1
               and('one') not in replay_1 and ('One') not in replay_1 
               and ('two') not in replay_1 and ('Two') not in replay_1
               and ('three') not in replay_1 and ('Three') not in replay_1
               and ('four') not in replay_1 and ('Four') not in replay_1
               and ('five') not in replay_1 and ('Five') not in replay_1
               and ('5') not in replay_1):
            print('You made a mistake')
# User input for knowing answers of user.
            replay_1 = input(prompt = """
Please introduce a number from 1-5:\n""").lower().capitalize()

# Creating conditions of specific scenes.
        if ('1') in replay_1 or ('one') in replay_1 or ('One') in replay_1:
           scene_1()
        elif ('2') in replay_1 or ('two') in replay_1 or ('Two') in replay_1:
            scene_2()
        elif (('3') in replay_1 or ('three') in replay_1 
              or ('Three') in replay_1):
            scene_3()
        elif ('4') in replay_1 or ('four') in replay_1 or ('Four') in replay_1:
            scene_4()
        elif ('5') in replay_1 or ('five') in replay_1 or ('Five') in replay_1:
            scene_5()   
            
    # Creating condition in case user dies, restart game or leave.            
    elif replay == "No":
        
        print("""
Hope you enjoyed, wish to see you soon!""")
    else:
         print("""
Hope you enjoyed, wish to see you soon!""")
# Calling scene 1 to start game.            
scene_1()

"""Juan Pedro Ballester Vives"""
# Out:
# Hi Mowgli, whilst living with the wolves you hear that there is an imminent
# threat of Shere Khan, that has set on you his target. You are forced to leave
# the pack. Your friend Bagheera takes you away in order to take you back to
# the human civilization.
#
#
#
# Bagheera asks you if agree, do you?
#
# Answer the question including 'yes' or 'no':
# djhd
#
#
# You have made a mistake, please answer again.
#
#
# Bagheera asks you if agree, do you?
#
# Answer the question including 'yes' or 'no':
# j djbd yes
#
#
#
# You scream to her: J djbd yes!, she is pleased to see that you are
# being reasonable, and that the jungle is too dangerous for you. She tells you
# to go up a tree for the night and you do just so.
#
#
# You are up in the tree, but a sudden voice appears making you sleepy and
# confused. You do not know what you should do since the same is happening to
# Bagheera.
# What do you do? - Please choose a number or the text in the answer.
#
# 1 - Jump of the tree.
# ...
